# %%
import seaborn as sns
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
deals= pd.read_csv('Sample_Data_Deals.csv')
deals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        199 non-null    object
#  1   OrderQuantity  199 non-null    int64
#  2   OrderValue     199 non-null    int64
#  3   Country        199 non-null    object
#  4   Deal Status    199 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 7.9+ KB

# %%
deals.mean(numeric_only=True)
# Out:
# OrderQuantity     2421.402010
# OrderValue       25381.105528
# dtype: float64

# %%
deals.describe(include='O')
# Out:
#         OrderID  Country Deal Status
# count       199      199         199
# unique       10       10           3
# top     OD38231  Germany         Won
# freq         39       37         105

# %%
#Count the total number of deals in each stage, horizontal bar plot
deals['Deal Status'].value_counts().sort_index(ascending=False).plot(kind='barh', colormap='seismic', alpha=0.6)
# Out:
# <Axes: ylabel='Deal Status'>

# %%
#Count number of deals in each Stage by Country
fig=plt.figure(figsize=(10,5))
ax=sns.countplot(x='Country', data=deals, hue='Deal Status', palette='rocket', alpha=0.8)
#ax.bar_label(ax.containers[0:2], fontsize=10);
plt.legend(fontsize='small', loc='upper right', bbox_to_anchor=(1.2, 1))
plt.tight_layout()
for container in ax.containers:
    ax.bar_label(container)

# %%
#Bar Plot
fig=plt.figure(figsize=(10,5))
r=sns.barplot(x='Deal Status',y='OrderValue',data=deals, 
            hue='Country', palette='rocket', alpha=0.7)
plt.legend(fontsize='small', loc='upper right', bbox_to_anchor=(1.2, 1))
#plt.xticks(rotation=45, ha='right')  # Adjust rotation angle as needed
plt.tight_layout()  # Adjust layout to prevent label cutoff#

# %%
#Swarm Plot
plt.figure(figsize=(17,7))
plt.style.use('ggplot')
plt.tight_layout()  # Adjust layout to prevent label cutoff
g=sns.catplot(
    data=deals, kind="swarm",
    x="Country", y="OrderQuantity", 
    hue='Country',col="Deal Status", palette="rocket", size=10, legend=False
)
# set rotation
g.set_xticklabels(rotation=30) 
#plt.legend(fontsize='small', loc='upper right', bbox_to_anchor=(1.2, 1))
